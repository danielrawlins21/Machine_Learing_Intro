# %%
import pandas as pd
import numpy as np
import scipy.cluster.hierarchy as shc
from sklearn.preprocessing import normalize
import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# C:\Users\danie\AppData\Local\Temp\ipykernel_12552\4132042688.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
data = pd.read_csv('../datasets/credit card/CC GENERAL.csv')
data.head()
# Out:
#   CUST_ID      BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0  C10001    40.900749           0.818182      95.40              0.00
# 1  C10002  3202.467416           0.909091       0.00              0.00
# 2  C10003  2495.148862           1.000000     773.17            773.17
# 3  C10004  1666.670542           0.636364    1499.00           1499.00
# 4  C10005   817.714335           1.000000      16.00             16.00
#
#    INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                    95.4      0.000000             0.166667
# 1                     0.0   6442.945483             0.000000
# 2                     0.0      0.000000             1.000000
# 3                     0.0    205.788017             0.083333
# 4                     0.0      0.000000             0.083333
#
#    ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 0                    0.000000                          0.083333
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8950 entries, 0 to 8949
# Data columns (total 18 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   CUST_ID                           8950 non-null   object
#  1   BALANCE                           8950 non-null   float64
#  2   BALANCE_FREQUENCY                 8950 non-null   float64
#  3   PURCHASES                         8950 non-null   float64
#  4   ONEOFF_PURCHASES                  8950 non-null   float64
#  5   INSTALLMENTS_PURCHASES            8950 non-null   float64
#  6   CASH_ADVANCE                      8950 non-null   float64
#  7   PURCHASES_FREQUENCY               8950 non-null   float64
#  8   ONEOFF_PURCHASES_FREQUENCY        8950 non-null   float64
#  9   PURCHASES_INSTALLMENTS_FREQUENCY  8950 non-null   float64
#  10  CASH_ADVANCE_FREQUENCY            8950 non-null   float64
# ...

# %%
data = data.drop('CUST_ID', axis=1)

# %%
data.describe()
# Out:
#             BALANCE  BALANCE_FREQUENCY     PURCHASES  ONEOFF_PURCHASES  \
# count   8950.000000        8950.000000   8950.000000       8950.000000
# mean    1564.474828           0.877271   1003.204834        592.437371
# std     2081.531879           0.236904   2136.634782       1659.887917
# min        0.000000           0.000000      0.000000          0.000000
# 25%      128.281915           0.888889     39.635000          0.000000
# 50%      873.385231           1.000000    361.280000         38.000000
# 75%     2054.140036           1.000000   1110.130000        577.405000
# max    19043.138560           1.000000  49039.570000      40761.250000
#
#        INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# count             8950.000000   8950.000000          8950.000000
# mean               411.067645    978.871112             0.490351
# std                904.338115   2097.163877             0.401371
# min                  0.000000      0.000000             0.000000
# ...

# %%
nulls_col = data.isnull().sum()
nulls_col
# Out:
# BALANCE                               0
# BALANCE_FREQUENCY                     0
# PURCHASES                             0
# ONEOFF_PURCHASES                      0
# INSTALLMENTS_PURCHASES                0
# CASH_ADVANCE                          0
# PURCHASES_FREQUENCY                   0
# ONEOFF_PURCHASES_FREQUENCY            0
# PURCHASES_INSTALLMENTS_FREQUENCY      0
# CASH_ADVANCE_FREQUENCY                0
# CASH_ADVANCE_TRX                      0
# PURCHASES_TRX                         0
# CREDIT_LIMIT                          1
# PAYMENTS                              0
# MINIMUM_PAYMENTS                    313
# PRC_FULL_PAYMENT                      0
# TENURE                                0
# dtype: int64

# %%
import seaborn as sns

sns.heatmap(data=data.isnull(), cbar=False, cmap='viridis')
plt.title('HeatMAp of nulls')
plt.show()

# %%
data.fillna(method='ffill', inplace=True)
data.isnull().sum()
# Out:
# C:\Users\danie\AppData\Local\Temp\ipykernel_12552\3919082295.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   data.fillna(method='ffill', inplace=True)
# BALANCE                             0
# BALANCE_FREQUENCY                   0
# PURCHASES                           0
# ONEOFF_PURCHASES                    0
# INSTALLMENTS_PURCHASES              0
# CASH_ADVANCE                        0
# PURCHASES_FREQUENCY                 0
# ONEOFF_PURCHASES_FREQUENCY          0
# PURCHASES_INSTALLMENTS_FREQUENCY    0
# CASH_ADVANCE_FREQUENCY              0
# CASH_ADVANCE_TRX                    0
# PURCHASES_TRX                       0
# CREDIT_LIMIT                        0
# PAYMENTS                            0
# MINIMUM_PAYMENTS                    0
# PRC_FULL_PAYMENT                    0
# TENURE                              0
# dtype: int64

# %%
data.describe()
# Out:
#             BALANCE  BALANCE_FREQUENCY     PURCHASES  ONEOFF_PURCHASES  \
# count   8950.000000        8950.000000   8950.000000       8950.000000
# mean    1564.474828           0.877271   1003.204834        592.437371
# std     2081.531879           0.236904   2136.634782       1659.887917
# min        0.000000           0.000000      0.000000          0.000000
# 25%      128.281915           0.888889     39.635000          0.000000
# 50%      873.385231           1.000000    361.280000         38.000000
# 75%     2054.140036           1.000000   1110.130000        577.405000
# max    19043.138560           1.000000  49039.570000      40761.250000
#
#        INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# count             8950.000000   8950.000000          8950.000000
# mean               411.067645    978.871112             0.490351
# std                904.338115   2097.163877             0.401371
# min                  0.000000      0.000000             0.000000
# ...

# %%
data_scaled = normalize(data)
data_scaled = pd.DataFrame(data_scaled, columns=data.columns)
data_scaled.head()
# Out:
#     BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0  0.039353           0.000787   0.091790          0.000000
# 1  0.293876           0.000083   0.000000          0.000000
# 2  0.310798           0.000125   0.096307          0.096307
# 3  0.208403           0.000080   0.187437          0.187437
# 4  0.504284           0.000617   0.009867          0.009867
#
#    INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                 0.09179      0.000000             0.000160
# 1                 0.00000      0.591240             0.000000
# 2                 0.00000      0.000000             0.000125
# 3                 0.00000      0.025732             0.000010
# 4                 0.00000      0.000000             0.000051
#
#    ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 0                    0.000000                           0.00008
# 1                    0.000000                           0.00000
# ...

# %%
from sklearn.decomposition import PCA

pca = PCA()
data_PCA = pca.fit_transform(data_scaled)

# %%
explained_variance = pca.explained_variance_ratio_
explained_variance
# Out:
# array([3.32411051e-01, 2.76047409e-01, 1.64257985e-01, 8.92579321e-02,
#        7.51853585e-02, 5.13618023e-02, 1.14045180e-02, 3.36388152e-05,
#        2.26650990e-05, 1.36892153e-05, 3.77893509e-06, 8.72510293e-08,
#        3.51754014e-08, 3.30846767e-08, 1.28436646e-08, 3.15797395e-09,
#        1.21911674e-09])

# %%
cum_explained_variance = pca.explained_variance_ratio_.cumsum()
cum_explained_variance
# Out:
# array([0.33241105, 0.60845846, 0.77271644, 0.86197438, 0.93715973,
#        0.98852154, 0.99992606, 0.99995969, 0.99998236, 0.99999605,
#        0.99999983, 0.99999991, 0.99999995, 0.99999998, 1.        ,
#        1.        , 1.        ])

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8, 5))
plt.plot(range(1, len(explained_variance) + 1), cum_explained_variance, marker='o', linestyle='--')
plt.title('Gráfico de Codo')
plt.xlabel('Número de Componentes')
plt.ylabel('Varianza Explicada Acumulada')
plt.grid()
plt.show()

# %% [markdown]
# Tomar solo 6 componentes para hacer la jerarquizacion

# %%
pca_cols = ['PC'+ str(i+1) for i in range(pca.n_components_)]
df_pca = pd.DataFrame(data_PCA, columns=pca_cols)
df_pca.head()
# Out:
#         PC1       PC2       PC3       PC4       PC5       PC6       PC7  \
# 0 -0.315576 -0.044823  0.024746  0.135670 -0.035808  0.008799 -0.045394
# 1  0.317328 -0.156866  0.368285 -0.023922  0.069666  0.017549 -0.030491
# 2 -0.206978 -0.183004 -0.123505 -0.082968 -0.050956 -0.061521  0.010509
# 3 -0.279409 -0.118059 -0.127551 -0.114479  0.096201 -0.099587 -0.003363
# 4  0.140988 -0.090323 -0.093426 -0.002797 -0.323127 -0.039816  0.006485
#
#         PC8       PC9      PC10      PC11      PC12      PC13      PC14  \
# 0  0.004380 -0.005749 -0.000171 -0.000909  0.000250 -0.000170  0.000005
# 1 -0.001506  0.001204  0.000032 -0.001654 -0.000008  0.000003  0.000018
# 2 -0.001360  0.000982  0.000036  0.000025 -0.000034 -0.000006 -0.000010
# 3 -0.002748 -0.000848  0.000078  0.000077  0.000015  0.000023 -0.000020
# 4  0.002435 -0.002666 -0.000064 -0.000791  0.000076 -0.000117  0.000055
#
#        PC15          PC16      PC17
# 0 -0.000036 -5.157406e-05 -0.000034
# ...

# %%
loadings = pd.DataFrame(pca.components_.T, columns=pca_cols, index=data_scaled.columns)
print(loadings)
# Out:
#                                        PC1       PC2       PC3       PC4  \
# BALANCE                           0.515198 -0.373621 -0.447617 -0.487165
# BALANCE_FREQUENCY                 0.000047 -0.000009 -0.000181  0.000055
# PURCHASES                        -0.051034  0.521892 -0.259962 -0.350562
# ONEOFF_PURCHASES                 -0.000266  0.294987 -0.148360 -0.416871
# INSTALLMENTS_PURCHASES           -0.050844  0.227100 -0.111763  0.066689
# CASH_ADVANCE                      0.429023 -0.257343  0.615449 -0.192454
# PURCHASES_FREQUENCY              -0.000145  0.000201 -0.000166  0.000100
# ONEOFF_PURCHASES_FREQUENCY       -0.000008  0.000090 -0.000063 -0.000135
# PURCHASES_INSTALLMENTS_FREQUENCY -0.000130  0.000154 -0.000127  0.000171
# CASH_ADVANCE_FREQUENCY            0.000081 -0.000055  0.000064 -0.000035
# CASH_ADVANCE_TRX                  0.001881 -0.001068  0.001770 -0.000655
# PURCHASES_TRX                    -0.001573  0.006945 -0.004850 -0.002087
# ...

# %%
pca = PCA(n_components=6)
data_PCA = pca.fit_transform(data_scaled)

# %% [markdown]
# ### Dendograms with PCA

# %%
plt.title("Dendograms with PCA")
dendo = shc.dendrogram(shc.linkage(data_PCA, method='ward'))

# %%
from sklearn.cluster import AgglomerativeClustering
cluster = AgglomerativeClustering(n_clusters=4, metric='euclidean', linkage='ward')
cluster.fit_predict(data_PCA)
# Out:
# array([3, 1, 3, ..., 3, 3, 2], dtype=int64)

# %%
pca_cols = ['PC'+ str(i+1) for i in range(pca.n_components_)]
df_pca = pd.DataFrame(data_PCA, columns=pca_cols)
df_pca.head()
# Out:
#         PC1       PC2       PC3       PC4       PC5       PC6
# 0 -0.315576 -0.044823  0.024746  0.135670 -0.035808  0.008799
# 1  0.317328 -0.156866  0.368285 -0.023922  0.069666  0.017549
# 2 -0.206978 -0.183004 -0.123505 -0.082968 -0.050956 -0.061521
# 3 -0.279409 -0.118059 -0.127551 -0.114479  0.096201 -0.099587
# 4  0.140988 -0.090323 -0.093426 -0.002797 -0.323127 -0.039816

# %%
plt.scatter(df_pca['PC1'], df_pca['PC2'], c = cluster.labels_)

# %%
plt.scatter(df_pca['PC1'], df_pca['PC3'], c = cluster.labels_)

# %%
plt.scatter(df_pca['PC1'], df_pca['PC4'], c = cluster.labels_)

# %%
plt.scatter(df_pca['PC1'], df_pca['PC5'], c = cluster.labels_)

# %%
import seaborn as sns
df_pca['cluster'] = cluster.fit_predict(data_PCA)

sns.pairplot(df_pca, kind='scatter',hue='cluster')

# %% [markdown]
# ### Old Dendograms without PCA

# %%
plt.title("Dendograms")
dend = shc.dendrogram(shc.linkage(data_scaled, method='ward'))

# %%
from sklearn.cluster import AgglomerativeClustering
cluster = AgglomerativeClustering(n_clusters=3, metric='euclidean', linkage='ward')
cluster.fit_predict(data_scaled)
# Out:
# array([1, 0, 2, ..., 1, 1, 0], dtype=int64)

# %%
plt.scatter(data_scaled['BALANCE'], data_scaled['PAYMENTS'], c = cluster.labels_)
